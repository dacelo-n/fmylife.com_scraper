# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load data

# %%
df = pd.read_json('../data/results.json')
df
# Out:
#                     title                                               body  \
# 0          Request denied  \nToday, I told my wife I wanted a divorce. I ...
# 1      All over the place  \nToday, I run a business with my partner, and...
# 2       Smack my bitch up  \nToday, I got naked after coming home. It's s...
# 3                    Boo!        \nToday, my toaster scared me. Again. FML\n
# 4            The struggle  \nToday, I've realized how badly my social anx...
# ...                   ...                                                ...
# 14222                None  \nToday, my 19-year-old daughter got a haircut...
# 14223                None  \nToday, my phone cut out during a call for a ...
# 14224                None  \nToday, it's my birthday. My dad showed up to...
# 14225                None  \nToday, I told my boyfriend about a friend-wi...
# 14226                None  \nToday, I saw a message on my boyfriend's pho...
#
#         agree deserve
# ...

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# Make all words lowercase, remove \n and remove rows that have None values

# %%
df = df.dropna(subset=['title'])
df
# Out:
#                     title                                               body  \
# 0          Request denied  \nToday, I told my wife I wanted a divorce. I ...
# 1      All over the place  \nToday, I run a business with my partner, and...
# 2       Smack my bitch up  \nToday, I got naked after coming home. It's s...
# 3                    Boo!        \nToday, my toaster scared me. Again. FML\n
# 4            The struggle  \nToday, I've realized how badly my social anx...
# ...                   ...                                                ...
# 14197           Rush hour  \nToday, whilst heading out the door to go to ...
# 14198            Finally!  \nToday, it's been so long since my husband ha...
# 14203         Hummmmmmmmm  \nToday, I moved into my brand new apartment, ...
# 14206              Bitten  \nToday, I had to explain to a lady that the r...
# 14215         Gamer watch  \nToday, my boyfriend and I were having sex. A...
#
#         agree deserve
# ...

# %%
df['body'] = df['body'].str.replace('\n', '')
